# %%
import ml_metrics

# %%
ml_metrics.mapk(
    [[3, 6, 1, 2, 5]],
    [[1, 2]],
    2)
# Out:
# 1.0

# %%
ml_metrics.mapk(
    [[3, 6, 1, 2, 5]],
    [[10, 2]],
    2)
# Out:
# 0.25

# %%
ml_metrics.mapk(
    [[3, 6, 1, 2, 5]],
    [[1, 20]],
    2)
# Out:
# 0.5

# %%
ml_metrics.mapk(
    [[1, 2, 5, 3, 6]],
    [[1, 2]],
    2)
# Out:
# 1.0

# %%
ml_metrics.mapk(
    [[1, 2, 5, 3, 6]],
    [[10, 2]],
    2)
# Out:
# 0.25

# %%
ml_metrics.mapk(
    [[1, 2, 5, 3, 6]],
    [[1, 20]],
    2)
# Out:
# 0.5

# %%
ml_metrics.mapk(
    [[2, 1, 5, 3, 6]],
    [[1, 20]],
    2)
# Out:
# 0.5

# %%
ml_metrics.mapk(
    [[2, 5, 3, 1, 6]],
    [[1, 20]],
    2)
# Out:
# 0.5
